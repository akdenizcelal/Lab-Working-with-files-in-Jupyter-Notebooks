# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# # Introduction
#
# In this notebook, Data Science Tools and Ecosystem are summarised.

# %% [markdown]
# **Objectives:**
#
# - How to List Popular Languages for Data Science
# - How to identify commonly used libraries for data analysis
# - Explore open-source development environments for Data Science
# - How to perform basic arithmetic operations in Python
# - How to convert minutes to hours in Python

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
#
# 1. **Python** - versatile and widely used for data analysis, visualisation, and machine learning.
# 2. **R** - specialised in statistics and data visualisation.
# 3. **SQL** - essential for querying and managing databases.
# 4. **Julia** - used for high-performance numerical computing.

# %% [markdown]
# Some of the commonly used libraries by Data Scientists include:
#
# 1. **pandas** - for data manipulation and analysis.
# 2. **NumPy** - for numerical computing and arrays.
# 3. **matplotlib** - for data visualization.
# 4. **scikit-learn** - for machine learning.

# %% [markdown]
# | Data Science Tools |
# |-------------------|
# | Jupyter Notebook  |
# | VS Code           |
# | RStudio           |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python.

# %%
# This is a simple arithmetic expression to multiply then add integers
result = (3 * 4) + 5
result
# Out:
# 17

# %%
# This will convert 200 minutes to hours by dividing by 60
minutes = 200
hours = minutes / 60
hours
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Author
#
# Celal Akdeniz
